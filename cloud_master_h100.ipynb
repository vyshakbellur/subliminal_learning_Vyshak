# %% [markdown]
# # 🧬 Subliminal Learning: Cloud Master Runner (H100/A100)
#
# ### 🚀 Step 1: Robust Environment Setup
# This cell handles GitHub cloning and ensures the cloud VM is in the correct directory.

# %%
import os
import sys

# 1. Clean up old clones and re-clone latest from GitHub
# !rm -rf subliminal_learning_Vyshak
# !git clone https://github.com/vyshakbellur/subliminal_learning_Vyshak.git

# 2. Force move into the project directory
# %cd /content/subliminal_learning_Vyshak/

# 3. Verify file exists
if os.path.exists('run_real_mgnify.py'):
    print("✅ Found run_real_mgnify.py! Ready to run.")
else:
    print("❌ ERROR: Project files missing. Check the GitHub URL.")

# 4. Install Dependencies
# %pip install torch biopython numpy pandas matplotlib seaborn gdown

# %% [markdown]
# ### 🛡️ Step 2: GPU Tier Verification
# Confirm your H100/A100 is connected.

# %%
import torch
if torch.cuda.is_available():
    name = torch.cuda.get_device_name(0)
    print(f"✅ Successfully connected to GPU: {name}")
else:
    print("❌ GPU not detected. Go to Runtime -> Change runtime type -> GPU.")

# %% [markdown]
# ### 🧪 Step 3: Launch Scaling Experiment
# This launches the high-performance MASTER RUN on all available environmental samples.

# %%
# Launch the MASSIVE SCALE RUN (Hierarchical VAE-MoE)
# --n-per-env 0 tells the script to download ALL available samples per study
# %run run_real_mgnify.py --arch hierarchical --n-per-env 0 --epochs 5 --device cuda
